# %% [markdown]
# # DataCamp Submission Draft
#
# This notebook is a placeholder for the competition-facing workflow. The local repo should generate a baseline prediction file first; then this notebook can be adapted to match DataCamp's exact required output format.

# %%
import pandas as pd

group_fixtures = pd.read_csv('data/group_fixtures.csv')
knockout_slots = pd.read_csv('data/knockout_slots.csv')

group_fixtures.head()
